# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("C:\\Users\Shivansh\Downloads\healthcare-dataset-stroke-data.csv")
df.drop("id",axis=1,inplace=True)

# %%
df.to_csv("Stroke_Disease.csv",index=False)
