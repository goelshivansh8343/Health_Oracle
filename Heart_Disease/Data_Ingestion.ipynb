# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("C:\\Users\Shivansh\Downloads\cleaned_merged_heart_dataset.csv")

# %%
df.to_csv("Heart.csv")
